# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.preprocessing import normalize

# %%
data = pd.read_csv("Data.csv")
data
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg      60      0          20     12      0      0      0      0
# 1       neg      82      0          68     40      0      0      0      0
# 2       neg   66002      2         212    112      0      0      0      0
# 3       neg   59816     na        1010    936      0      0      0      0
# 4       neg    1814     na         156    140      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 15995   neg   81852     na  2130706432    892      0      0      0      0
# 15996   neg      18      0          52     46      8     26      0      0
# 15997   neg   79636     na        1670   1518      0      0      0      0
# 15998   neg     110     na          36     32      0      0      0      0
# 15999   neg       8      0           6      4      2      2      0      0
#
#       ag_002  ...  ee_002  ee_003  ee_004  ee_005   ee_006  ee_007  ee_008  \
# ...

# %% [markdown]
# ## missing value some

# %%
for i in data.columns:
    data[i] = [np.nan if x in ['na'] else x for x in data[i]]
# Out:
# 0        neg
# 1        neg
# 2        neg
# 3        neg
# 4        neg
#         ...
# 15995    neg
# 15996    neg
# 15997    neg
# 15998    neg
# 15999    neg
# Name: class, Length: 16000, dtype: object
# 0           60
# 1           82
# 2        66002
# 3        59816
# 4         1814
#          ...
# 15995    81852
# 15996       18
# 15997    79636
# 15998      110
# 15999        8
# Name: aa_000, Length: 16000, dtype: int64
# 0          0
# 1          0
# 2          2
# 3        NaN
# 4        NaN
#         ...
# 15995    NaN
# 15996      0
# 15997    NaN
# 15998    NaN
# 15999      0
# Name: ab_000, Length: 16000, dtype: object
# 0                20
# 1                68
# 2               212
# 3              1010
# 4               156
#             ...
# 15995    2130706432
# 15996            52
# 15997          1670
# 15998            36
# 15999             6
# Name: ac_000, Length: 16000, dtype: object
# 0          12
# 1          40
# 2         112
# 3         936
# ...

# %%
# Out:
#        class  aa_000  ab_000  ac_000  ad_000  ae_000  af_000  ag_000  ag_001  \
# 0      False   False   False   False   False   False   False   False   False
# 1      False   False   False   False   False   False   False   False   False
# 2      False   False   False   False   False   False   False   False   False
# 3      False   False    True   False   False   False   False   False   False
# 4      False   False    True   False   False   False   False   False   False
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15995  False   False    True   False   False   False   False   False   False
# 15996  False   False   False   False   False   False   False   False   False
# 15997  False   False    True   False   False   False   False   False   False
# 15998  False   False    True   False   False   False   False   False   False
# 15999  False   False   False   False   False   False   False   False   False
#
# ...

# %%
data.shape
# Out:
# (16000, 171)

# %%
data.isna()
# Out:
#        class  aa_000  ab_000  ac_000  ad_000  ae_000  af_000  ag_000  ag_001  \
# 0      False   False   False   False   False   False   False   False   False
# 1      False   False   False   False   False   False   False   False   False
# 2      False   False   False   False   False   False   False   False   False
# 3      False   False   False   False   False   False   False   False   False
# 4      False   False   False   False   False   False   False   False   False
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15995  False   False   False   False   False   False   False   False   False
# 15996  False   False   False   False   False   False   False   False   False
# 15997  False   False   False   False   False   False   False   False   False
# 15998  False   False   False   False   False   False   False   False   False
# 15999  False   False   False   False   False   False   False   False   False
#
# ...

# %%
for i in data.columns:
    count = data.groupby(i).size()
    a = (count == 'na')
    print(a)
    print("**********")
# Out:
# class
# neg    False
# pos    False
# dtype: bool
# **********
# aa_000
# 0           False
# 2           False
# 4           False
# 6           False
# 8           False
#             ...
# 1833224     False
# 1851934     False
# 1855974     False
# 2255630     False
# 42949672    False
# Length: 9237, dtype: bool
# **********
# ab_000
# 0     False
# 10    False
# 12    False
# 14    False
# 16    False
# 18    False
# 2     False
# 20    False
# 22    False
# 24    False
# 26    False
# 28    False
# 32    False
# 38    False
# 4     False
# 58    False
# 6     False
# 8     False
# na    False
# dtype: bool
# **********
# ac_000
# 0       False
# 10      False
# 100     False
# 1000    False
# 1002    False
#         ...
# 9936    False
# 994     False
# 996     False
# 998     False
# na      False
# Length: 1312, dtype: bool
# **********
# ad_000
# 0       False
# 10      False
# 100     False
# 1000    False
# 1002    False
#         ...
# 992     False
# 994     False
# ...

# %%
data.isnull().sum()/len(data)*100
# Out:
# class      0.00000
# aa_000     0.00000
# ab_000    77.26875
# ac_000     5.78750
# ad_000    24.88125
#             ...
# ee_007     1.20000
# ee_008     1.20000
# ee_009     1.20000
# ef_000     4.76250
# eg_000     4.76250
# Length: 171, dtype: float64

# %%
variable = []
for i in range(data.columns.shape[0]):
    if a[i]<=50:
        variable.append(variables[i])

# %%
variable
# Out:
# ['class',
#  'aa_000',
#  'ac_000',
#  'ad_000',
#  'ae_000',
#  'af_000',
#  'ag_000',
#  'ag_001',
#  'ag_002',
#  'ag_003',
#  'ag_004',
#  'ag_005',
#  'ag_006',
#  'ag_007',
#  'ag_008',
#  'ag_009',
#  'ah_000',
#  'ai_000',
#  'aj_000',
#  'ak_000',
#  'al_000',
#  'am_0',
#  'an_000',
#  'ao_000',
#  'ap_000',
#  'aq_000',
#  'ar_000',
#  'as_000',
#  'at_000',
#  'au_000',
#  'av_000',
#  'ax_000',
#  'ay_000',
#  'ay_001',
#  'ay_002',
#  'ay_003',
#  'ay_004',
#  'ay_005',
#  'ay_006',
#  'ay_007',
#  'ay_008',
#  'ay_009',
#  'az_000',
#  'az_001',
#  'az_002',
#  'az_003',
#  'az_004',
#  'az_005',
#  'az_006',
#  'az_007',
#  'az_008',
#  'az_009',
#  'ba_000',
#  'ba_001',
#  'ba_002',
#  'ba_003',
#  'ba_004',
#  'ba_005',
#  'ba_006',
#  'ba_007',
#  'ba_008',
#  'ba_009',
#  'bb_000',
#  'bc_000',
#  'bd_000',
#  'be_000',
#  'bf_000',
#  'bg_000',
#  'bh_000',
#  'bi_000',
#  'bj_000',
#  'bk_000',
#  'bl_000',
#  'bs_000',
#  'bt_000',
#  'bu_000',
#  'bv_000',
# ...

# %%
new_data = data[variable]
new_data.head()
# Out:
#   class  aa_000 ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  ag_003  ...  \
# 0   neg      60     20     12      0      0      0      0      0    2682  ...
# 1   neg      82     68     40      0      0      0      0      0       0  ...
# 2   neg   66002    212    112      0      0      0      0      0  199486  ...
# 3   neg   59816   1010    936      0      0      0      0      0       0  ...
# 4   neg    1814    156    140      0      0      0      0      0       0  ...
#
#    ee_002  ee_003  ee_004  ee_005   ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0    1098     138     412     654       78      88       0      0      0
# 1    1068     276    1620     116       86     462       0      0      0
# 2  495076  380368  440134  269556  1315022  153680     516      0      0
# 3  540820  243270  483302  485332   431376  210074  281662   3232      0
# 4    7646    4144   18466   49782     3176     482      76      0      0
#
#   eg_000
# 0      0
# 1      0
# 2      0
# 3      0
# ...

# %%
new_data.isnull().sum()/len(new_data)*100
# Out:
# class      0.00000
# aa_000     0.00000
# ac_000     5.78750
# ad_000    24.88125
# ae_000     4.31250
#             ...
# ee_007     1.20000
# ee_008     1.20000
# ee_009     1.20000
# ef_000     4.76250
# eg_000     4.76250
# Length: 163, dtype: float64

# %%
new_data.shape, data.shape
# Out:
# ((16000, 163), (16000, 171))

# %% [markdown]
# ## Low variance filter

# %%
data1 = data.drop('class', axis=1)

# %%
data1.isnull().sum()
# Out:
# aa_000        0
# ab_000    12363
# ac_000      926
# ad_000     3981
# ae_000      690
#           ...
# ee_007      192
# ee_008      192
# ee_009      192
# ef_000      762
# eg_000      762
# Length: 170, dtype: int64

# %%
data1.replace(np.NaN,0,inplace = True)

# %%
normalize_data = normalize(data1)

# %%
scale_data = pd.DataFrame(normalize_data)
scale_data.var()
# Out:
# 0      1.383644e-03
# 1      8.434658e-13
# 2      1.332301e-01
# 3      2.654943e-09
# 4      1.229886e-11
#            ...
# 165    2.683218e-04
# 166    1.085034e-04
# 167    1.662297e-06
# 168    1.122451e-12
# 169    1.947788e-13
# Length: 170, dtype: float64

# %%
#storing the variance and name of variables

variance = scale_data.var()
columns = data1.columns

# %%
#saving the names of variables having variance more than a threshold value

df = [ ]

for i in range(0,len(variance)):
    if variance[i] >= 0.00035: #setting the threshold as 1%
        df.append(columns[i])
df
# Out:
# ['aa_000',
#  'ac_000',
#  'ag_004',
#  'ag_005',
#  'ag_006',
#  'ag_007',
#  'ah_000',
#  'an_000',
#  'ao_000',
#  'ap_000',
#  'ay_006',
#  'ay_007',
#  'ay_008',
#  'az_004',
#  'az_005',
#  'az_006',
#  'ba_000',
#  'ba_001',
#  'bb_000',
#  'bg_000',
#  'bi_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'bt_000',
#  'bu_000',
#  'bv_000',
#  'bx_000',
#  'cb_000',
#  'cc_000',
#  'cd_000',
#  'ci_000',
#  'ck_000',
#  'cn_003',
#  'cn_004',
#  'cn_005',
#  'cn_006',
#  'cq_000',
#  'cs_005',
#  'cs_006',
#  'cv_000',
#  'cx_000',
#  'dc_000',
#  'dl_000',
#  'dq_000',
#  'du_000',
#  'dv_000',
#  'dx_000',
#  'eb_000',
#  'ee_000',
#  'ee_001']

# %%
# creating a new dataframe using the above variables
data2 = data1[df]
data2
# Out:
#        aa_000      ac_000   ag_004   ag_005   ag_006   ag_007   ah_000  \
# 0          60          20     4736     3862     1846        0     3976
# 1          82          68      748    12594     3636        0     5244
# 2       66002         212  1358536  1952422   452706    25130  1891670
# 3       59816        1010   123922   984314  1680050  1135268  1772828
# 4        1814         156       72    17926    82834     3114    48978
# ...       ...         ...      ...      ...      ...      ...      ...
# 15995   81852  2130706432     5486   704012  3220278  1297498  2276100
# 15996      18          52     6444     3308     2720        0     3740
# 15997   79636        1670    15062  1991298  2768440   329148  2156280
# 15998     110          36      198     3730    27418      978    12790
# 15999       8           6     1350     3328     1126        0     2228
#
#         an_000   ao_000   ap_000  ...   cx_000   dc_000 dl_000    dq_000  \
# ...

# %% [markdown]
# ## High Correlation Filter

# %%
data2.astype(float)
correlation = data2.corr()
numeric_columns = data2.columns

high_corr = [ ]

for c1 in numeric_columns:
  for c2 in numeric_columns:
    if c1 != c2 and c2 not in high_corr and correlation[c1][c2] > 0.9:
      high_corr.append(c1)

data2=data2[high_corr]
data2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ac_000'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-e95b8f373f05> in <module>
#       7 for c1 in numeric_columns:
# ...
